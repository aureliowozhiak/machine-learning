# %% [markdown]
# # <font color='blue'>Data Science Academy - Matemática Para Machine Learning</font>

# %% [markdown]
# ## Estudo de Caso 5 - Compreendendo Como Funciona o Backpropagation

# %% [markdown]
# ## Parte 4 - Otimização com Stochastic Gradient Descent

# %% [markdown]
# Stochastic Gradient Descent (SGD) é uma versão de Gradient Descent, onde em cada passagem para a frente, obtemos um lote de dados com amostras aleatórias do conjunto de dados total. Aqui onde entra em cena o batch_size. Esse é o tamanho do lote. Idealmente, todo o conjunto de dados seria alimentado na rede neural em cada passagem para a frente, mas na prática isso acaba não sendo possível, devido a restrições de memória. SGD é uma aproximação de Gradient Descent, quanto mais lotes processados pela rede neural, melhor será a aproximação.

# %% [markdown]
# Uma implementação do SGD envolve:
#
# 1. Gerar lotes de dados de amostras aleatórias do conjunto de dados total.
#
# 2. Executar a rede para frente (Forward Pass) e para trás (Backward pass) para calcular o gradiente (com dados de (1)).
#
# 3. Aplicar a atualização de descida do gradiente.
#
# 4. Repetir as etapas 1-3 até a convergência ou o loop for parado por outro mecanismo (como o número de épocas, por exemplo).
#
# Se tudo correr bem, a perda da rede vai diminuindo, indicando pesos e bias mais úteis ao longo do tempo.

# %%
import numpy as np

class Neuronio:
    """
    Classe base para os nós da rede.

    Argumentos:

        "nodes_entrada": Uma lista de nós com arestas para este nó.
    """
    def __init__(self, nodes_entrada = []):
        """
        O construtor do nó (é executado quando o objeto é instanciado). 
        Define propriedades que podem ser usadas por todos os nós.
        """
        # Lista de nós com arestas para este nó.
        self.nodes_entrada = nodes_entrada
        
        # Lista de nós para os quais este nó gera saída.
        self.nodes_saida = []
        
        # O valor calculado por este nó. É definido executando o método forward().
        self.valor = None
        
        # Este objeto é um dicionário com pares chaves/valor entre {} 
        # As chaves (keys) são os inputs para este nó e o valores (values) são as paciais deste nó em relação ao input.
        self.gradientes = {}
        
        # Configuramos este nó como um nó de saída para todos os nós de entrada.
        for n in nodes_entrada:
            n.nodes_saida.append(self)

    def forward(self):
        """
        Todo o nó que usar essa classe como uma classe base, precisa definir seu próprio método "forward".
        """
        raise NotImplementedError

    def backward(self):
        """
        Todo o nó que usar essa classe como uma classe base, precisa definir seu próprio método "backward".
        """
        raise NotImplementedError



class Input(Neuronio):
    """
    Input genérico para a rede.
    """
    def __init__(self):
        # O construtor da classe base deve ser executado para configurar todas as propriedades aqui.
        #
        # A propriedade mais importante de Input é valor.
        # self.valor é definido na função topological_sort().
        Neuronio.__init__(self)

    def forward(self):
        # Nada a ser feito aqui.
        pass

    def backward(self):
        # Um nó de Input não possui entradas (pois ele já é a entrada) e assim o gradiente (derivada) é zero.
        # A palavra reservada "self", é referência para este objeto.
        self.gradientes = {self: 0}
        
        # Pesos e bias podem ser inputs, assim precisamos somar o gradiente de outros gradientes de saída
        for n in self.nodes_saida:
            self.gradientes[self] += n.gradientes[self]
            

class Linear(Neuronio):
    """
    Representa um nó que realiza transformação linear.
    """
    def __init__(self, X, W, b):
        # O construtor da classe base (nó). 
        # Pesos e bias são tratados como nós de entrada (nodes_entrada).
        Neuronio.__init__(self, [X, W, b])

    def forward(self):
        """
        Executa a matemática por trás da transformação linear.
        """
        X = self.nodes_entrada[0].valor
        W = self.nodes_entrada[1].valor
        b = self.nodes_entrada[2].valor
        self.valor = np.dot(X, W) + b

    def backward(self):
        """
        Calcula o gradiente com base nos valores de saída.
        """
        # Inicializa um parcial para cada um dos nodes_entrada.
        self.gradientes = {n: np.zeros_like(n.valor) for n in self.nodes_entrada}
        
        # Ciclo através dos outputs. 
        # O gradiente mudará dependendo de cada output, assim os gradientes são somados sobre todos os outputs.
        for n in self.nodes_saida:
            
            # Obtendo parcial da perda em relação a este nó.
            grad_cost = n.gradientes[self]
            
            # Definindo o parcial da perda em relação às entradas deste nó.
            self.gradientes[self.nodes_entrada[0]] += np.dot(grad_cost, self.nodes_entrada[1].valor.T)
            
            # Definindo o parcial da perda em relação aos pesos deste nó.
            self.gradientes[self.nodes_entrada[1]] += np.dot(self.nodes_entrada[0].valor.T, grad_cost)
            
            # Definindo o parcial da perda em relação ao bias deste nó.
            self.gradientes[self.nodes_entrada[2]] += np.sum(grad_cost, axis = 0, keepdims = False)


class Sigmoid(Neuronio):
    """
    Representa o nó da função de ativação Sigmoid.
    """
    def __init__(self, node):
        # O construtor da classe base.
        Neuronio.__init__(self, [node])

    def _sigmoid(self, x):
        """
        Este método é separado do `forward` porque ele também será usado com "backward".

        `x`: Um array Numpy.
        """
        return 1. / (1. + np.exp(-x))

    def forward(self):
        """
        Executa a função _sigmoid e define a variável self.valor
        """
        input_value = self.nodes_entrada[0].valor
        self.valor = self._sigmoid(input_value)

    def backward(self):
        """
        Calcula o gradiente usando a derivada da função sigmoid 
        
        O método backward da classe Sigmoid, soma as derivadas (é uma derivada normal quando há apenas uma variável) 
        em relação à única entrada sobre todos os nós de saída.
        """
        
        # Inicializa os gradientes com zero.
        self.gradientes = {n: np.zeros_like(n.valor) for n in self.nodes_entrada}
        
        # Soma a parcial em relação ao input sobre todos os outputs.
        for n in self.nodes_saida:
            grad_cost = n.gradientes[self]
            sigmoid = self.valor
            self.gradientes[self.nodes_entrada[0]] += sigmoid * (1 - sigmoid) * grad_cost


class MSE(Neuronio):
    def __init__(self, y, a):
        """
        Função de custo para calcular o erro médio quadrático.
        Deve ser usado como último nó da rede.
        """
        # Chamada ao construtor da classe base.
        Neuronio.__init__(self, [y, a])

    def forward(self):
        """
        Calcula o erro médio ao quadrado.
        """
        # Fazemos o reshape para evitar possíveis problemas nas operações de matrizes/vetores 
        #
        # Convertendo os 2 arrays (3,1) garantimos que o resultado será (3,1) e, assim, 
        # teremos uma subtração elementwise.
        y = self.nodes_entrada[0].valor.reshape(-1, 1)
        a = self.nodes_entrada[1].valor.reshape(-1, 1)

        self.m = self.nodes_entrada[0].valor.shape[0]
        
        # Salva o output computado para o backward pass.
        self.diff = y - a
        self.valor = np.mean(self.diff**2)

    def backward(self):
        """
        Calcula o gradiente do custo.
        """
        self.gradientes[self.nodes_entrada[0]] = (2 / self.m) * self.diff
        self.gradientes[self.nodes_entrada[1]] = (-2 / self.m) * self.diff


def topological_sort(feed_dict):
    """
    Classifica os nós em ordem topológica usando o Algoritmo de Kahn.

    `Feed_dict`: um dicionário em que a chave é um nó `Input` e o valor é o respectivo feed de valor para esse nó.

    Retorna uma lista de nós ordenados.
    """

    input_nodes = [n for n in feed_dict.keys()]

    G = {}
    nodes = [n for n in input_nodes]
    while len(nodes) > 0:
        n = nodes.pop(0)
        if n not in G:
            G[n] = {'in': set(), 'out': set()}
        for m in n.nodes_saida:
            if m not in G:
                G[m] = {'in': set(), 'out': set()}
            G[n]['out'].add(m)
            G[m]['in'].add(n)
            nodes.append(m)

    L = []
    S = set(input_nodes)
    while len(S) > 0:
        n = S.pop()

        if isinstance(n, Input):
            n.valor = feed_dict[n]

        L.append(n)
        for m in n.nodes_saida:
            G[n]['out'].remove(m)
            G[m]['in'].remove(n)
            if len(G[m]['in']) == 0:
                S.add(m)
    return L


def forward_and_backward(graph):
    """
    Executa uma passagem para a frente e uma passagem para trás através de uma lista de nós ordenados.

     Argumentos:

         `Graph`: O resultado de `topological_sort`.
    """
    # Forward pass
    for n in graph:
        n.forward()

    # Backward pass
    # O valor negativo no slice permite fazer uma cópia da mesma lista na ordem inversa.
    for n in graph[::-1]:
        n.backward()


def sgd_update(params, learning_rate = 1e-2):
    """
    Atualiza o valor de cada parâmetro treinável com o SGD.

    Argumentos:

         `Trainables`: uma lista de nós `Input` que representam pesos / bias.
         `Learning_rate`: a taxa de aprendizado.
    """
    # Executa o SGD
    #
    # Loop sobre todos os parâmetros
    for t in params:
        # Alterar o valor do parâmetro, subtraindo a taxa de aprendizado 
        # multiplicado pela parte do custo em relação a esse parâmetro
        partial = t.gradientes[t]
        t.valor -= learning_rate * partial

# %% [markdown]
# ### Executando o Grafo

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_boston.html

# %%
import numpy as np
from sklearn.datasets import load_boston
from sklearn.utils import shuffle, resample

# Carrega os dados
data = load_boston()

# Variáveis de entrada e saída para treinamento supervisionado
X_ = data['data']
y_ = data['target']

# Normaliza os dados
X_ = (X_ - np.mean(X_, axis = 0)) / np.std(X_, axis = 0)

# Número de features e número de neurônios
n_features = X_.shape[1]
n_hidden = 10

# Define valores randômicos para inicializar pesos e bias
W1_ = np.random.randn(n_features, n_hidden)
b1_ = np.zeros(n_hidden)
W2_ = np.random.randn(n_hidden, 1)
b2_ = np.zeros(1)

# Rede Neural
X, y = Input(), Input()
W1, b1 = Input(), Input()
W2, b2 = Input(), Input()

l1 = Linear(X, W1, b1)
s1 = Sigmoid(l1)
l2 = Linear(s1, W2, b2)
cost = MSE(y, l2)

# Define o feed_dict
feed_dict = {
    X: X_,
    y: y_,
    W1: W1_,
    b1: b1_,
    W2: W2_,
    b2: b2_
}

# Número de epochs (altere esse valor para ver as mudanças no resultado)
epochs = 1000

# Número total de exemplos
m = X_.shape[0]

# Batch size
batch_size = 11
steps_per_epoch = m // batch_size

# Define o grafo computacional
graph = topological_sort(feed_dict)

# Valores que serão aprendidos pela rede
params = [W1, b1, W2, b2]

# Número total de exemplos
print("Número Total de Exemplos = {}".format(m))

# Treinamento do modelo
for i in range(epochs):
    loss = 0
    for j in range(steps_per_epoch):
        
        # Passo 1 - Testa aleatoriamente um lote de exemplos
        X_batch, y_batch = resample(X_, y_, n_samples = batch_size)

        # Reset dos valores de X e y 
        X.valor = X_batch
        y.valor = y_batch

        # Passo 2 - Forward e Backpropagation
        forward_and_backward(graph)

        # Passo 3 - Otimização por SGD
        sgd_update(params)

        loss += graph[-1].valor

    print("Epoch: {}, Custo: {:.3f}".format(i+1, loss/steps_per_epoch))
# Out:
# Número Total de Exemplos = 506
# Epoch: 1, Custo: 137.029
# Epoch: 2, Custo: 36.451
# Epoch: 3, Custo: 21.682
# Epoch: 4, Custo: 23.894
# Epoch: 5, Custo: 23.786
# Epoch: 6, Custo: 20.405
# Epoch: 7, Custo: 26.579
# Epoch: 8, Custo: 18.325
# Epoch: 9, Custo: 15.669
# Epoch: 10, Custo: 20.981
# Epoch: 11, Custo: 17.762
# Epoch: 12, Custo: 15.604
# Epoch: 13, Custo: 13.883
# Epoch: 14, Custo: 15.487
# Epoch: 15, Custo: 11.780
# Epoch: 16, Custo: 13.371
# Epoch: 17, Custo: 13.429
# Epoch: 18, Custo: 13.689
# Epoch: 19, Custo: 12.558
# Epoch: 20, Custo: 11.345
# Epoch: 21, Custo: 12.382
# Epoch: 22, Custo: 13.404
# Epoch: 23, Custo: 12.184
# Epoch: 24, Custo: 8.530
# Epoch: 25, Custo: 10.271
# Epoch: 26, Custo: 9.166
# Epoch: 27, Custo: 9.317
# Epoch: 28, Custo: 9.497
# Epoch: 29, Custo: 10.519
# Epoch: 30, Custo: 9.466
# Epoch: 31, Custo: 10.189
# Epoch: 32, Custo: 10.157
# Epoch: 33, Custo: 7.484
# Epoch: 34, Custo: 6.629
# Epoch: 35, Custo: 9.137
# Epoch: 36, Custo: 9.142
# Epoch: 37, Custo: 9.709
# Epoch: 38, Custo: 8.723
# Epoch: 39, Custo: 7.594
# Epoch: 40, Custo: 8.581
# Epoch: 41, Custo: 10.675
# Epoch: 42, Custo: 7.562
# Epoch: 43, Custo: 11.131
# Epoch: 44, Custo: 7.972
# Epoch: 45, Custo: 8.061
# Epoch: 46, Custo: 7.962
# Epoch: 47, Custo: 7.296
# Epoch: 48, Custo: 8.745
# Epoch: 49, Custo: 7.198
# Epoch: 50, Custo: 7.636
# Epoch: 51, Custo: 9.062
# Epoch: 52, Custo: 5.456
# Epoch: 53, Custo: 8.716
# Epoch: 54, Custo: 6.657
# Epoch: 55, Custo: 5.703
# Epoch: 56, Custo: 6.364
# Epoch: 57, Custo: 6.784
# Epoch: 58, Custo: 7.806
# Epoch: 59, Custo: 6.991
# Epoch: 60, Custo: 6.648
# Epoch: 61, Custo: 8.272
# Epoch: 62, Custo: 7.295
# Epoch: 63, Custo: 6.413
# Epoch: 64, Custo: 6.795
# Epoch: 65, Custo: 6.998
# Epoch: 66, Custo: 7.634
# Epoch: 67, Custo: 6.463
# Epoch: 68, Custo: 7.361
# Epoch: 69, Custo: 6.711
# Epoch: 70, Custo: 9.880
# Epoch: 71, Custo: 6.524
# Epoch: 72, Custo: 6.377
# Epoch: 73, Custo: 5.772
# Epoch: 74, Custo: 5.576
# Epoch: 75, Custo: 6.706
# Epoch: 76, Custo: 8.711
# Epoch: 77, Custo: 6.037
# Epoch: 78, Custo: 6.767
# Epoch: 79, Custo: 7.324
# Epoch: 80, Custo: 7.999
# Epoch: 81, Custo: 7.306
# Epoch: 82, Custo: 6.612
# Epoch: 83, Custo: 6.411
# Epoch: 84, Custo: 5.834
# Epoch: 85, Custo: 6.357
# Epoch: 86, Custo: 7.027
# Epoch: 87, Custo: 5.677
# Epoch: 88, Custo: 6.006
# Epoch: 89, Custo: 6.478
# Epoch: 90, Custo: 6.831
# Epoch: 91, Custo: 5.741
# Epoch: 92, Custo: 5.727
# Epoch: 93, Custo: 6.469
# Epoch: 94, Custo: 6.816
# Epoch: 95, Custo: 6.421
# Epoch: 96, Custo: 6.392
# Epoch: 97, Custo: 6.385
# Epoch: 98, Custo: 5.936
# Epoch: 99, Custo: 5.865
# Epoch: 100, Custo: 6.258
# Epoch: 101, Custo: 4.405
# Epoch: 102, Custo: 7.022
# Epoch: 103, Custo: 5.531
# Epoch: 104, Custo: 5.816
# Epoch: 105, Custo: 5.719
# Epoch: 106, Custo: 6.691
# Epoch: 107, Custo: 7.046
# Epoch: 108, Custo: 6.333
# Epoch: 109, Custo: 5.076
# Epoch: 110, Custo: 5.834
# Epoch: 111, Custo: 5.707
# Epoch: 112, Custo: 6.818
# Epoch: 113, Custo: 7.266
# Epoch: 114, Custo: 6.573
# Epoch: 115, Custo: 6.371
# Epoch: 116, Custo: 6.306
# Epoch: 117, Custo: 7.511
# Epoch: 118, Custo: 6.534
# Epoch: 119, Custo: 5.777
# Epoch: 120, Custo: 5.956
# Epoch: 121, Custo: 6.986
# Epoch: 122, Custo: 6.349
# Epoch: 123, Custo: 6.135
# Epoch: 124, Custo: 6.170
# Epoch: 125, Custo: 5.502
# Epoch: 126, Custo: 5.357
# Epoch: 127, Custo: 6.646
# Epoch: 128, Custo: 5.488
# Epoch: 129, Custo: 5.317
# Epoch: 130, Custo: 5.806
# Epoch: 131, Custo: 6.158
# Epoch: 132, Custo: 7.377
# Epoch: 133, Custo: 6.056
# Epoch: 134, Custo: 6.691
# Epoch: 135, Custo: 5.665
# Epoch: 136, Custo: 5.002
# Epoch: 137, Custo: 5.346
# Epoch: 138, Custo: 6.114
# Epoch: 139, Custo: 6.105
# Epoch: 140, Custo: 6.059
# Epoch: 141, Custo: 5.867
# Epoch: 142, Custo: 4.825
# Epoch: 143, Custo: 4.238
# Epoch: 144, Custo: 6.570
# Epoch: 145, Custo: 5.944
# Epoch: 146, Custo: 6.328
# Epoch: 147, Custo: 6.470
# Epoch: 148, Custo: 5.987
# Epoch: 149, Custo: 5.542
# Epoch: 150, Custo: 6.045
# Epoch: 151, Custo: 5.408
# Epoch: 152, Custo: 5.291
# Epoch: 153, Custo: 5.357
# Epoch: 154, Custo: 6.047
# Epoch: 155, Custo: 5.549
# Epoch: 156, Custo: 6.066
# Epoch: 157, Custo: 6.109
# Epoch: 158, Custo: 7.043
# Epoch: 159, Custo: 5.666
# Epoch: 160, Custo: 6.935
# Epoch: 161, Custo: 5.470
# Epoch: 162, Custo: 5.508
# Epoch: 163, Custo: 5.065
# Epoch: 164, Custo: 5.709
# Epoch: 165, Custo: 5.107
# Epoch: 166, Custo: 5.011
# Epoch: 167, Custo: 6.567
# Epoch: 168, Custo: 5.545
# Epoch: 169, Custo: 4.948
# Epoch: 170, Custo: 6.137
# Epoch: 171, Custo: 4.925
# Epoch: 172, Custo: 5.457
# Epoch: 173, Custo: 5.321
# Epoch: 174, Custo: 5.890
# Epoch: 175, Custo: 5.343
# Epoch: 176, Custo: 5.524
# Epoch: 177, Custo: 5.586
# Epoch: 178, Custo: 7.348
# Epoch: 179, Custo: 6.028
# Epoch: 180, Custo: 6.017
# Epoch: 181, Custo: 5.161
# Epoch: 182, Custo: 5.128
# Epoch: 183, Custo: 5.245
# Epoch: 184, Custo: 4.666
# Epoch: 185, Custo: 5.970
# Epoch: 186, Custo: 6.198
# Epoch: 187, Custo: 5.254
# Epoch: 188, Custo: 5.758
# Epoch: 189, Custo: 6.915
# Epoch: 190, Custo: 5.382
# Epoch: 191, Custo: 5.622
# Epoch: 192, Custo: 5.257
# Epoch: 193, Custo: 6.494
# Epoch: 194, Custo: 6.270
# Epoch: 195, Custo: 5.473
# Epoch: 196, Custo: 5.899
# Epoch: 197, Custo: 5.746
# Epoch: 198, Custo: 5.087
# Epoch: 199, Custo: 7.033
# Epoch: 200, Custo: 6.366
# Epoch: 201, Custo: 5.505
# Epoch: 202, Custo: 5.759
# Epoch: 203, Custo: 6.122
# Epoch: 204, Custo: 6.350
# Epoch: 205, Custo: 5.469
# Epoch: 206, Custo: 5.092
# Epoch: 207, Custo: 5.389
# Epoch: 208, Custo: 6.059
# Epoch: 209, Custo: 4.740
# Epoch: 210, Custo: 5.556
# Epoch: 211, Custo: 4.892
# Epoch: 212, Custo: 5.449
# Epoch: 213, Custo: 5.903
# Epoch: 214, Custo: 4.797
# Epoch: 215, Custo: 5.848
# Epoch: 216, Custo: 5.544
# Epoch: 217, Custo: 6.376
# Epoch: 218, Custo: 4.853
# Epoch: 219, Custo: 5.269
# Epoch: 220, Custo: 5.006
# Epoch: 221, Custo: 6.647
# Epoch: 222, Custo: 6.275
# Epoch: 223, Custo: 5.600
# Epoch: 224, Custo: 4.909
# Epoch: 225, Custo: 7.171
# Epoch: 226, Custo: 5.271
# Epoch: 227, Custo: 4.861
# Epoch: 228, Custo: 4.927
# Epoch: 229, Custo: 4.923
# Epoch: 230, Custo: 5.105
# Epoch: 231, Custo: 6.152
# Epoch: 232, Custo: 5.363
# Epoch: 233, Custo: 5.702
# Epoch: 234, Custo: 5.859
# Epoch: 235, Custo: 5.074
# Epoch: 236, Custo: 4.523
# Epoch: 237, Custo: 5.081
# Epoch: 238, Custo: 4.431
# Epoch: 239, Custo: 5.449
# Epoch: 240, Custo: 5.530
# Epoch: 241, Custo: 6.531
# Epoch: 242, Custo: 5.136
# Epoch: 243, Custo: 4.753
# Epoch: 244, Custo: 6.016
# Epoch: 245, Custo: 5.922
# Epoch: 246, Custo: 4.773
# Epoch: 247, Custo: 5.511
# Epoch: 248, Custo: 5.016
# Epoch: 249, Custo: 5.950
# Epoch: 250, Custo: 5.104
# Epoch: 251, Custo: 4.685
# Epoch: 252, Custo: 5.548
# Epoch: 253, Custo: 5.094
# Epoch: 254, Custo: 5.826
# Epoch: 255, Custo: 5.450
# Epoch: 256, Custo: 5.036
# Epoch: 257, Custo: 5.997
# Epoch: 258, Custo: 5.242
# Epoch: 259, Custo: 5.067
# Epoch: 260, Custo: 5.959
# Epoch: 261, Custo: 4.233
# Epoch: 262, Custo: 4.147
# Epoch: 263, Custo: 4.588
# Epoch: 264, Custo: 5.364
# Epoch: 265, Custo: 5.240
# Epoch: 266, Custo: 4.066
# Epoch: 267, Custo: 5.981
# Epoch: 268, Custo: 5.381
# Epoch: 269, Custo: 6.327
# Epoch: 270, Custo: 5.489
# Epoch: 271, Custo: 7.177
# Epoch: 272, Custo: 5.515
# Epoch: 273, Custo: 4.684
# Epoch: 274, Custo: 4.339
# Epoch: 275, Custo: 5.248
# Epoch: 276, Custo: 5.679
# Epoch: 277, Custo: 4.902
# Epoch: 278, Custo: 4.525
# Epoch: 279, Custo: 5.135
# Epoch: 280, Custo: 5.077
# Epoch: 281, Custo: 4.852
# Epoch: 282, Custo: 5.029
# Epoch: 283, Custo: 4.499
# Epoch: 284, Custo: 5.240
# Epoch: 285, Custo: 5.023
# Epoch: 286, Custo: 4.407
# Epoch: 287, Custo: 4.977
# Epoch: 288, Custo: 4.787
# Epoch: 289, Custo: 4.884
# Epoch: 290, Custo: 4.912
# Epoch: 291, Custo: 5.534
# Epoch: 292, Custo: 6.101
# Epoch: 293, Custo: 5.819
# Epoch: 294, Custo: 5.217
# Epoch: 295, Custo: 5.394
# Epoch: 296, Custo: 5.529
# Epoch: 297, Custo: 5.521
# Epoch: 298, Custo: 5.247
# Epoch: 299, Custo: 4.779
# Epoch: 300, Custo: 4.578
# Epoch: 301, Custo: 5.053
# Epoch: 302, Custo: 4.789
# Epoch: 303, Custo: 5.237
# Epoch: 304, Custo: 4.271
# Epoch: 305, Custo: 5.569
# Epoch: 306, Custo: 4.651
# Epoch: 307, Custo: 5.433
# Epoch: 308, Custo: 4.490
# Epoch: 309, Custo: 5.573
# Epoch: 310, Custo: 5.345
# Epoch: 311, Custo: 5.397
# Epoch: 312, Custo: 4.409
# Epoch: 313, Custo: 6.078
# Epoch: 314, Custo: 4.893
# Epoch: 315, Custo: 4.653
# Epoch: 316, Custo: 5.406
# Epoch: 317, Custo: 5.541
# Epoch: 318, Custo: 4.902
# Epoch: 319, Custo: 4.658
# Epoch: 320, Custo: 5.404
# Epoch: 321, Custo: 5.356
# Epoch: 322, Custo: 5.638
# Epoch: 323, Custo: 5.188
# Epoch: 324, Custo: 5.424
# Epoch: 325, Custo: 5.333
# Epoch: 326, Custo: 5.086
# Epoch: 327, Custo: 5.499
# Epoch: 328, Custo: 4.575
# Epoch: 329, Custo: 5.017
# Epoch: 330, Custo: 5.064
# Epoch: 331, Custo: 4.225
# Epoch: 332, Custo: 5.827
# Epoch: 333, Custo: 4.569
# Epoch: 334, Custo: 5.172
# Epoch: 335, Custo: 6.251
# Epoch: 336, Custo: 5.488
# Epoch: 337, Custo: 5.164
# Epoch: 338, Custo: 5.357
# Epoch: 339, Custo: 5.216
# Epoch: 340, Custo: 4.264
# Epoch: 341, Custo: 5.154
# Epoch: 342, Custo: 5.440
# Epoch: 343, Custo: 4.976
# Epoch: 344, Custo: 5.280
# Epoch: 345, Custo: 3.859
# Epoch: 346, Custo: 5.237
# Epoch: 347, Custo: 5.763
# Epoch: 348, Custo: 4.513
# Epoch: 349, Custo: 4.867
# Epoch: 350, Custo: 5.420
# Epoch: 351, Custo: 4.977
# Epoch: 352, Custo: 5.673
# Epoch: 353, Custo: 5.480
# Epoch: 354, Custo: 4.537
# Epoch: 355, Custo: 5.448
# Epoch: 356, Custo: 5.496
# Epoch: 357, Custo: 5.395
# Epoch: 358, Custo: 5.943
# Epoch: 359, Custo: 5.282
# Epoch: 360, Custo: 4.822
# Epoch: 361, Custo: 5.285
# Epoch: 362, Custo: 4.584
# Epoch: 363, Custo: 5.669
# Epoch: 364, Custo: 4.446
# Epoch: 365, Custo: 5.778
# Epoch: 366, Custo: 5.136
# Epoch: 367, Custo: 4.858
# Epoch: 368, Custo: 5.439
# Epoch: 369, Custo: 5.530
# Epoch: 370, Custo: 4.942
# Epoch: 371, Custo: 5.777
# Epoch: 372, Custo: 5.375
# Epoch: 373, Custo: 4.916
# Epoch: 374, Custo: 4.887
# Epoch: 375, Custo: 4.794
# Epoch: 376, Custo: 4.668
# Epoch: 377, Custo: 5.074
# Epoch: 378, Custo: 5.381
# Epoch: 379, Custo: 4.026
# Epoch: 380, Custo: 5.195
# Epoch: 381, Custo: 5.284
# Epoch: 382, Custo: 4.774
# Epoch: 383, Custo: 4.863
# Epoch: 384, Custo: 5.358
# Epoch: 385, Custo: 6.247
# Epoch: 386, Custo: 5.909
# Epoch: 387, Custo: 4.524
# Epoch: 388, Custo: 5.281
# Epoch: 389, Custo: 4.511
# Epoch: 390, Custo: 4.655
# Epoch: 391, Custo: 4.478
# Epoch: 392, Custo: 4.435
# Epoch: 393, Custo: 4.564
# Epoch: 394, Custo: 5.233
# Epoch: 395, Custo: 5.575
# Epoch: 396, Custo: 4.337
# Epoch: 397, Custo: 4.787
# Epoch: 398, Custo: 4.868
# Epoch: 399, Custo: 4.922
# Epoch: 400, Custo: 5.464
# Epoch: 401, Custo: 5.570
# Epoch: 402, Custo: 5.505
# Epoch: 403, Custo: 5.745
# Epoch: 404, Custo: 4.920
# Epoch: 405, Custo: 5.125
# Epoch: 406, Custo: 4.827
# Epoch: 407, Custo: 4.511
# Epoch: 408, Custo: 5.429
# Epoch: 409, Custo: 4.704
# Epoch: 410, Custo: 6.645
# Epoch: 411, Custo: 5.054
# Epoch: 412, Custo: 5.608
# Epoch: 413, Custo: 5.538
# Epoch: 414, Custo: 4.718
# Epoch: 415, Custo: 5.492
# Epoch: 416, Custo: 5.415
# Epoch: 417, Custo: 5.217
# Epoch: 418, Custo: 4.566
# Epoch: 419, Custo: 4.773
# Epoch: 420, Custo: 5.041
# Epoch: 421, Custo: 4.525
# Epoch: 422, Custo: 5.436
# Epoch: 423, Custo: 4.828
# Epoch: 424, Custo: 5.397
# Epoch: 425, Custo: 5.768
# Epoch: 426, Custo: 4.855
# Epoch: 427, Custo: 5.700
# Epoch: 428, Custo: 5.076
# Epoch: 429, Custo: 5.177
# Epoch: 430, Custo: 4.694
# Epoch: 431, Custo: 4.697
# Epoch: 432, Custo: 4.563
# Epoch: 433, Custo: 5.576
# Epoch: 434, Custo: 5.115
# Epoch: 435, Custo: 4.989
# Epoch: 436, Custo: 4.930
# Epoch: 437, Custo: 4.535
# Epoch: 438, Custo: 4.529
# Epoch: 439, Custo: 4.866
# Epoch: 440, Custo: 5.335
# Epoch: 441, Custo: 5.043
# Epoch: 442, Custo: 5.269
# Epoch: 443, Custo: 4.972
# Epoch: 444, Custo: 4.938
# Epoch: 445, Custo: 5.209
# Epoch: 446, Custo: 4.470
# Epoch: 447, Custo: 5.436
# Epoch: 448, Custo: 4.420
# Epoch: 449, Custo: 5.222
# Epoch: 450, Custo: 5.113
# Epoch: 451, Custo: 4.284
# Epoch: 452, Custo: 3.707
# Epoch: 453, Custo: 4.796
# Epoch: 454, Custo: 4.758
# Epoch: 455, Custo: 5.652
# Epoch: 456, Custo: 4.645
# Epoch: 457, Custo: 4.744
# Epoch: 458, Custo: 4.459
# Epoch: 459, Custo: 5.276
# Epoch: 460, Custo: 4.087
# Epoch: 461, Custo: 4.237
# Epoch: 462, Custo: 4.782
# Epoch: 463, Custo: 4.933
# Epoch: 464, Custo: 4.763
# Epoch: 465, Custo: 5.356
# Epoch: 466, Custo: 5.614
# Epoch: 467, Custo: 4.314
# Epoch: 468, Custo: 4.562
# Epoch: 469, Custo: 4.151
# Epoch: 470, Custo: 4.435
# Epoch: 471, Custo: 4.723
# Epoch: 472, Custo: 5.167
# Epoch: 473, Custo: 5.455
# Epoch: 474, Custo: 5.679
# Epoch: 475, Custo: 5.615
# Epoch: 476, Custo: 5.110
# Epoch: 477, Custo: 4.596
# Epoch: 478, Custo: 4.809
# Epoch: 479, Custo: 4.897
# Epoch: 480, Custo: 5.041
# Epoch: 481, Custo: 4.629
# Epoch: 482, Custo: 4.305
# Epoch: 483, Custo: 5.054
# Epoch: 484, Custo: 5.075
# Epoch: 485, Custo: 4.279
# Epoch: 486, Custo: 4.772
# Epoch: 487, Custo: 4.990
# Epoch: 488, Custo: 4.463
# Epoch: 489, Custo: 4.103
# Epoch: 490, Custo: 4.475
# Epoch: 491, Custo: 4.632
# Epoch: 492, Custo: 5.191
# Epoch: 493, Custo: 4.646
# Epoch: 494, Custo: 4.736
# Epoch: 495, Custo: 4.541
# Epoch: 496, Custo: 5.614
# Epoch: 497, Custo: 4.957
# Epoch: 498, Custo: 4.993
# Epoch: 499, Custo: 4.907
# Epoch: 500, Custo: 4.649
# Epoch: 501, Custo: 4.703
# Epoch: 502, Custo: 4.343
# Epoch: 503, Custo: 5.036
# Epoch: 504, Custo: 5.371
# Epoch: 505, Custo: 5.114
# Epoch: 506, Custo: 5.192
# Epoch: 507, Custo: 4.646
# Epoch: 508, Custo: 4.631
# Epoch: 509, Custo: 5.320
# Epoch: 510, Custo: 5.143
# Epoch: 511, Custo: 4.263
# Epoch: 512, Custo: 4.763
# Epoch: 513, Custo: 5.431
# Epoch: 514, Custo: 4.054
# Epoch: 515, Custo: 4.552
# Epoch: 516, Custo: 5.235
# Epoch: 517, Custo: 4.460
# Epoch: 518, Custo: 4.796
# Epoch: 519, Custo: 4.836
# Epoch: 520, Custo: 4.451
# Epoch: 521, Custo: 4.534
# Epoch: 522, Custo: 4.824
# Epoch: 523, Custo: 4.609
# Epoch: 524, Custo: 4.704
# Epoch: 525, Custo: 5.232
# Epoch: 526, Custo: 4.445
# Epoch: 527, Custo: 5.167
# Epoch: 528, Custo: 5.318
# Epoch: 529, Custo: 4.540
# Epoch: 530, Custo: 3.880
# Epoch: 531, Custo: 4.425
# Epoch: 532, Custo: 4.967
# Epoch: 533, Custo: 4.542
# Epoch: 534, Custo: 4.080
# Epoch: 535, Custo: 4.809
# Epoch: 536, Custo: 4.466
# Epoch: 537, Custo: 5.577
# Epoch: 538, Custo: 4.916
# Epoch: 539, Custo: 5.299
# Epoch: 540, Custo: 4.660
# Epoch: 541, Custo: 4.071
# Epoch: 542, Custo: 4.293
# Epoch: 543, Custo: 4.504
# Epoch: 544, Custo: 4.993
# Epoch: 545, Custo: 4.898
# Epoch: 546, Custo: 4.876
# Epoch: 547, Custo: 6.074
# Epoch: 548, Custo: 4.612
# Epoch: 549, Custo: 4.915
# Epoch: 550, Custo: 4.457
# Epoch: 551, Custo: 4.502
# Epoch: 552, Custo: 4.907
# Epoch: 553, Custo: 4.080
# Epoch: 554, Custo: 4.947
# Epoch: 555, Custo: 5.204
# Epoch: 556, Custo: 4.393
# Epoch: 557, Custo: 4.593
# Epoch: 558, Custo: 5.049
# Epoch: 559, Custo: 5.197
# Epoch: 560, Custo: 5.253
# Epoch: 561, Custo: 4.213
# Epoch: 562, Custo: 4.371
# Epoch: 563, Custo: 5.055
# Epoch: 564, Custo: 4.399
# Epoch: 565, Custo: 4.403
# Epoch: 566, Custo: 5.006
# Epoch: 567, Custo: 5.107
# Epoch: 568, Custo: 4.813
# Epoch: 569, Custo: 4.726
# Epoch: 570, Custo: 4.698
# Epoch: 571, Custo: 5.160
# Epoch: 572, Custo: 5.313
# Epoch: 573, Custo: 4.920
# Epoch: 574, Custo: 4.582
# Epoch: 575, Custo: 4.608
# Epoch: 576, Custo: 4.617
# Epoch: 577, Custo: 5.041
# Epoch: 578, Custo: 4.763
# Epoch: 579, Custo: 5.040
# Epoch: 580, Custo: 4.503
# Epoch: 581, Custo: 4.458
# Epoch: 582, Custo: 4.691
# Epoch: 583, Custo: 4.893
# Epoch: 584, Custo: 4.771
# Epoch: 585, Custo: 4.624
# Epoch: 586, Custo: 4.680
# Epoch: 587, Custo: 4.291
# Epoch: 588, Custo: 5.559
# Epoch: 589, Custo: 4.078
# Epoch: 590, Custo: 4.423
# Epoch: 591, Custo: 4.030
# Epoch: 592, Custo: 4.887
# Epoch: 593, Custo: 5.372
# Epoch: 594, Custo: 4.185
# Epoch: 595, Custo: 4.659
# Epoch: 596, Custo: 4.370
# Epoch: 597, Custo: 4.554
# Epoch: 598, Custo: 4.559
# Epoch: 599, Custo: 4.587
# Epoch: 600, Custo: 4.799
# Epoch: 601, Custo: 4.932
# Epoch: 602, Custo: 5.081
# Epoch: 603, Custo: 4.634
# Epoch: 604, Custo: 4.251
# Epoch: 605, Custo: 4.817
# Epoch: 606, Custo: 4.370
# Epoch: 607, Custo: 4.324
# Epoch: 608, Custo: 4.456
# Epoch: 609, Custo: 5.066
# Epoch: 610, Custo: 4.763
# Epoch: 611, Custo: 4.686
# Epoch: 612, Custo: 4.294
# Epoch: 613, Custo: 4.872
# Epoch: 614, Custo: 4.539
# Epoch: 615, Custo: 4.565
# Epoch: 616, Custo: 4.958
# Epoch: 617, Custo: 4.994
# Epoch: 618, Custo: 4.772
# Epoch: 619, Custo: 4.655
# Epoch: 620, Custo: 4.940
# Epoch: 621, Custo: 4.591
# Epoch: 622, Custo: 4.060
# Epoch: 623, Custo: 4.419
# Epoch: 624, Custo: 4.063
# Epoch: 625, Custo: 4.536
# Epoch: 626, Custo: 4.894
# Epoch: 627, Custo: 4.857
# Epoch: 628, Custo: 4.027
# Epoch: 629, Custo: 4.170
# Epoch: 630, Custo: 5.067
# Epoch: 631, Custo: 4.881
# Epoch: 632, Custo: 5.245
# Epoch: 633, Custo: 5.095
# Epoch: 634, Custo: 4.122
# Epoch: 635, Custo: 4.600
# Epoch: 636, Custo: 4.407
# Epoch: 637, Custo: 4.683
# Epoch: 638, Custo: 4.555
# Epoch: 639, Custo: 4.645
# Epoch: 640, Custo: 4.958
# Epoch: 641, Custo: 4.173
# Epoch: 642, Custo: 4.468
# Epoch: 643, Custo: 3.829
# Epoch: 644, Custo: 5.075
# Epoch: 645, Custo: 4.922
# Epoch: 646, Custo: 4.102
# Epoch: 647, Custo: 4.814
# Epoch: 648, Custo: 4.469
# Epoch: 649, Custo: 4.698
# Epoch: 650, Custo: 3.601
# Epoch: 651, Custo: 4.260
# Epoch: 652, Custo: 4.143
# Epoch: 653, Custo: 3.965
# Epoch: 654, Custo: 4.375
# Epoch: 655, Custo: 4.779
# Epoch: 656, Custo: 4.929
# Epoch: 657, Custo: 5.434
# Epoch: 658, Custo: 4.057
# Epoch: 659, Custo: 4.622
# Epoch: 660, Custo: 5.095
# Epoch: 661, Custo: 4.599
# Epoch: 662, Custo: 5.049
# Epoch: 663, Custo: 4.705
# Epoch: 664, Custo: 4.652
# Epoch: 665, Custo: 4.913
# Epoch: 666, Custo: 4.194
# Epoch: 667, Custo: 4.680
# Epoch: 668, Custo: 3.743
# Epoch: 669, Custo: 4.703
# Epoch: 670, Custo: 4.300
# Epoch: 671, Custo: 4.308
# Epoch: 672, Custo: 4.876
# Epoch: 673, Custo: 4.324
# Epoch: 674, Custo: 4.177
# Epoch: 675, Custo: 4.740
# Epoch: 676, Custo: 4.642
# Epoch: 677, Custo: 3.824
# Epoch: 678, Custo: 4.589
# Epoch: 679, Custo: 4.239
# Epoch: 680, Custo: 5.144
# Epoch: 681, Custo: 4.002
# Epoch: 682, Custo: 4.991
# Epoch: 683, Custo: 4.733
# Epoch: 684, Custo: 4.294
# Epoch: 685, Custo: 4.018
# Epoch: 686, Custo: 4.803
# Epoch: 687, Custo: 4.877
# Epoch: 688, Custo: 4.864
# Epoch: 689, Custo: 4.324
# Epoch: 690, Custo: 4.085
# Epoch: 691, Custo: 4.417
# Epoch: 692, Custo: 4.999
# Epoch: 693, Custo: 4.253
# Epoch: 694, Custo: 4.066
# Epoch: 695, Custo: 4.552
# Epoch: 696, Custo: 4.311
# Epoch: 697, Custo: 4.949
# Epoch: 698, Custo: 4.276
# Epoch: 699, Custo: 5.195
# Epoch: 700, Custo: 4.381
# Epoch: 701, Custo: 4.919
# Epoch: 702, Custo: 4.547
# Epoch: 703, Custo: 5.039
# Epoch: 704, Custo: 4.538
# Epoch: 705, Custo: 4.516
# Epoch: 706, Custo: 4.397
# Epoch: 707, Custo: 3.931
# Epoch: 708, Custo: 4.364
# Epoch: 709, Custo: 4.894
# Epoch: 710, Custo: 4.140
# Epoch: 711, Custo: 4.323
# Epoch: 712, Custo: 4.522
# Epoch: 713, Custo: 3.811
# Epoch: 714, Custo: 4.489
# Epoch: 715, Custo: 4.200
# Epoch: 716, Custo: 4.649
# Epoch: 717, Custo: 4.489
# Epoch: 718, Custo: 4.602
# Epoch: 719, Custo: 4.269
# Epoch: 720, Custo: 4.358
# Epoch: 721, Custo: 3.751
# Epoch: 722, Custo: 4.307
# Epoch: 723, Custo: 4.038
# Epoch: 724, Custo: 4.622
# Epoch: 725, Custo: 4.675
# Epoch: 726, Custo: 4.370
# Epoch: 727, Custo: 5.080
# Epoch: 728, Custo: 4.639
# Epoch: 729, Custo: 4.089
# Epoch: 730, Custo: 4.662
# Epoch: 731, Custo: 4.239
# Epoch: 732, Custo: 4.201
# Epoch: 733, Custo: 3.915
# Epoch: 734, Custo: 5.518
# Epoch: 735, Custo: 4.683
# Epoch: 736, Custo: 4.242
# Epoch: 737, Custo: 4.074
# Epoch: 738, Custo: 4.090
# Epoch: 739, Custo: 4.213
# Epoch: 740, Custo: 4.359
# Epoch: 741, Custo: 4.446
# Epoch: 742, Custo: 4.370
# Epoch: 743, Custo: 3.880
# Epoch: 744, Custo: 4.322
# Epoch: 745, Custo: 4.736
# Epoch: 746, Custo: 4.577
# Epoch: 747, Custo: 4.499
# Epoch: 748, Custo: 3.747
# Epoch: 749, Custo: 5.271
# Epoch: 750, Custo: 4.391
# Epoch: 751, Custo: 5.248
# Epoch: 752, Custo: 4.553
# Epoch: 753, Custo: 4.195
# Epoch: 754, Custo: 4.453
# Epoch: 755, Custo: 5.016
# Epoch: 756, Custo: 4.308
# Epoch: 757, Custo: 4.254
# Epoch: 758, Custo: 4.751
# Epoch: 759, Custo: 4.000
# Epoch: 760, Custo: 4.484
# Epoch: 761, Custo: 4.598
# Epoch: 762, Custo: 3.855
# Epoch: 763, Custo: 4.140
# Epoch: 764, Custo: 4.338
# Epoch: 765, Custo: 4.317
# Epoch: 766, Custo: 4.513
# Epoch: 767, Custo: 4.270
# Epoch: 768, Custo: 4.588
# Epoch: 769, Custo: 3.895
# Epoch: 770, Custo: 4.012
# Epoch: 771, Custo: 4.477
# Epoch: 772, Custo: 4.678
# Epoch: 773, Custo: 4.024
# Epoch: 774, Custo: 4.967
# Epoch: 775, Custo: 5.182
# Epoch: 776, Custo: 4.419
# Epoch: 777, Custo: 4.642
# Epoch: 778, Custo: 4.029
# Epoch: 779, Custo: 4.237
# Epoch: 780, Custo: 4.043
# Epoch: 781, Custo: 4.668
# Epoch: 782, Custo: 3.909
# Epoch: 783, Custo: 4.847
# Epoch: 784, Custo: 4.706
# Epoch: 785, Custo: 3.979
# Epoch: 786, Custo: 4.322
# Epoch: 787, Custo: 4.402
# Epoch: 788, Custo: 5.096
# Epoch: 789, Custo: 4.446
# Epoch: 790, Custo: 4.800
# Epoch: 791, Custo: 4.018
# Epoch: 792, Custo: 4.553
# Epoch: 793, Custo: 3.310
# Epoch: 794, Custo: 4.684
# Epoch: 795, Custo: 4.232
# Epoch: 796, Custo: 4.184
# Epoch: 797, Custo: 4.545
# Epoch: 798, Custo: 4.638
# Epoch: 799, Custo: 4.993
# Epoch: 800, Custo: 4.840
# Epoch: 801, Custo: 4.276
# Epoch: 802, Custo: 4.773
# Epoch: 803, Custo: 4.026
# Epoch: 804, Custo: 4.275
# Epoch: 805, Custo: 4.640
# Epoch: 806, Custo: 5.191
# Epoch: 807, Custo: 4.366
# Epoch: 808, Custo: 4.227
# Epoch: 809, Custo: 4.837
# Epoch: 810, Custo: 4.222
# Epoch: 811, Custo: 4.460
# Epoch: 812, Custo: 4.195
# Epoch: 813, Custo: 4.309
# Epoch: 814, Custo: 4.125
# Epoch: 815, Custo: 4.230
# Epoch: 816, Custo: 4.304
# Epoch: 817, Custo: 3.988
# Epoch: 818, Custo: 4.499
# Epoch: 819, Custo: 3.935
# Epoch: 820, Custo: 4.694
# Epoch: 821, Custo: 3.910
# Epoch: 822, Custo: 4.353
# Epoch: 823, Custo: 3.660
# Epoch: 824, Custo: 4.070
# Epoch: 825, Custo: 4.583
# Epoch: 826, Custo: 3.461
# Epoch: 827, Custo: 4.004
# Epoch: 828, Custo: 4.472
# Epoch: 829, Custo: 4.345
# Epoch: 830, Custo: 4.322
# Epoch: 831, Custo: 4.304
# Epoch: 832, Custo: 5.117
# Epoch: 833, Custo: 4.206
# Epoch: 834, Custo: 4.487
# Epoch: 835, Custo: 4.696
# Epoch: 836, Custo: 4.548
# Epoch: 837, Custo: 4.766
# Epoch: 838, Custo: 4.547
# Epoch: 839, Custo: 4.118
# Epoch: 840, Custo: 4.525
# Epoch: 841, Custo: 5.132
# Epoch: 842, Custo: 4.097
# Epoch: 843, Custo: 4.559
# Epoch: 844, Custo: 4.255
# Epoch: 845, Custo: 4.320
# Epoch: 846, Custo: 3.923
# Epoch: 847, Custo: 4.357
# Epoch: 848, Custo: 4.021
# Epoch: 849, Custo: 4.123
# Epoch: 850, Custo: 5.109
# Epoch: 851, Custo: 4.379
# Epoch: 852, Custo: 4.036
# Epoch: 853, Custo: 4.296
# Epoch: 854, Custo: 4.257
# Epoch: 855, Custo: 4.669
# Epoch: 856, Custo: 4.371
# Epoch: 857, Custo: 5.166
# Epoch: 858, Custo: 4.663
# Epoch: 859, Custo: 4.366
# Epoch: 860, Custo: 5.305
# Epoch: 861, Custo: 3.770
# Epoch: 862, Custo: 4.240
# Epoch: 863, Custo: 4.152
# Epoch: 864, Custo: 4.604
# Epoch: 865, Custo: 4.401
# Epoch: 866, Custo: 3.853
# Epoch: 867, Custo: 3.713
# Epoch: 868, Custo: 4.324
# Epoch: 869, Custo: 4.211
# Epoch: 870, Custo: 4.350
# Epoch: 871, Custo: 3.853
# Epoch: 872, Custo: 3.347
# Epoch: 873, Custo: 4.138
# Epoch: 874, Custo: 3.652
# Epoch: 875, Custo: 4.601
# Epoch: 876, Custo: 4.388
# Epoch: 877, Custo: 4.475
# Epoch: 878, Custo: 4.319
# Epoch: 879, Custo: 4.365
# Epoch: 880, Custo: 3.729
# Epoch: 881, Custo: 3.966
# Epoch: 882, Custo: 4.160
# Epoch: 883, Custo: 3.954
# Epoch: 884, Custo: 4.764
# Epoch: 885, Custo: 4.724
# Epoch: 886, Custo: 4.201
# Epoch: 887, Custo: 5.530
# Epoch: 888, Custo: 3.604
# Epoch: 889, Custo: 4.416
# Epoch: 890, Custo: 4.047
# Epoch: 891, Custo: 4.306
# Epoch: 892, Custo: 3.585
# Epoch: 893, Custo: 4.333
# Epoch: 894, Custo: 4.167
# Epoch: 895, Custo: 3.780
# Epoch: 896, Custo: 4.249
# Epoch: 897, Custo: 4.418
# Epoch: 898, Custo: 4.511
# Epoch: 899, Custo: 4.162
# Epoch: 900, Custo: 3.957
# Epoch: 901, Custo: 4.100
# Epoch: 902, Custo: 4.443
# Epoch: 903, Custo: 3.996
# Epoch: 904, Custo: 4.155
# Epoch: 905, Custo: 4.238
# Epoch: 906, Custo: 4.798
# Epoch: 907, Custo: 4.787
# Epoch: 908, Custo: 3.881
# Epoch: 909, Custo: 3.898
# Epoch: 910, Custo: 4.201
# Epoch: 911, Custo: 4.266
# Epoch: 912, Custo: 4.407
# Epoch: 913, Custo: 3.493
# Epoch: 914, Custo: 4.545
# Epoch: 915, Custo: 4.221
# Epoch: 916, Custo: 4.096
# Epoch: 917, Custo: 4.364
# Epoch: 918, Custo: 3.672
# Epoch: 919, Custo: 4.257
# Epoch: 920, Custo: 4.083
# Epoch: 921, Custo: 3.570
# Epoch: 922, Custo: 4.353
# Epoch: 923, Custo: 4.171
# Epoch: 924, Custo: 4.244
# Epoch: 925, Custo: 4.132
# Epoch: 926, Custo: 4.243
# Epoch: 927, Custo: 4.235
# Epoch: 928, Custo: 4.465
# Epoch: 929, Custo: 4.620
# Epoch: 930, Custo: 4.118
# Epoch: 931, Custo: 3.794
# Epoch: 932, Custo: 3.999
# Epoch: 933, Custo: 3.988
# Epoch: 934, Custo: 3.687
# Epoch: 935, Custo: 4.550
# Epoch: 936, Custo: 4.144
# Epoch: 937, Custo: 3.837
# Epoch: 938, Custo: 4.352
# Epoch: 939, Custo: 4.308
# Epoch: 940, Custo: 3.682
# Epoch: 941, Custo: 4.271
# Epoch: 942, Custo: 4.156
# Epoch: 943, Custo: 3.751
# Epoch: 944, Custo: 4.369
# Epoch: 945, Custo: 4.137
# Epoch: 946, Custo: 4.154
# Epoch: 947, Custo: 3.977
# Epoch: 948, Custo: 3.886
# Epoch: 949, Custo: 4.069
# Epoch: 950, Custo: 4.288
# Epoch: 951, Custo: 4.639
# Epoch: 952, Custo: 3.985
# Epoch: 953, Custo: 4.109
# Epoch: 954, Custo: 4.324
# Epoch: 955, Custo: 4.634
# Epoch: 956, Custo: 4.230
# Epoch: 957, Custo: 4.102
# Epoch: 958, Custo: 3.784
# Epoch: 959, Custo: 4.688
# Epoch: 960, Custo: 4.196
# Epoch: 961, Custo: 3.944
# Epoch: 962, Custo: 3.945
# Epoch: 963, Custo: 4.407
# Epoch: 964, Custo: 4.110
# Epoch: 965, Custo: 4.371
# Epoch: 966, Custo: 4.302
# Epoch: 967, Custo: 4.664
# Epoch: 968, Custo: 4.054
# Epoch: 969, Custo: 3.807
# Epoch: 970, Custo: 4.508
# Epoch: 971, Custo: 4.674
# Epoch: 972, Custo: 5.013
# Epoch: 973, Custo: 4.216
# Epoch: 974, Custo: 4.021
# Epoch: 975, Custo: 4.161
# Epoch: 976, Custo: 3.555
# Epoch: 977, Custo: 4.662
# Epoch: 978, Custo: 4.090
# Epoch: 979, Custo: 4.007
# Epoch: 980, Custo: 3.931
# Epoch: 981, Custo: 4.909
# Epoch: 982, Custo: 4.656
# Epoch: 983, Custo: 4.185
# Epoch: 984, Custo: 4.086
# Epoch: 985, Custo: 4.321
# Epoch: 986, Custo: 4.666
# Epoch: 987, Custo: 4.448
# Epoch: 988, Custo: 4.059
# Epoch: 989, Custo: 4.485
# Epoch: 990, Custo: 4.595
# Epoch: 991, Custo: 4.392
# Epoch: 992, Custo: 4.367
# Epoch: 993, Custo: 4.423
# Epoch: 994, Custo: 4.297
# Epoch: 995, Custo: 4.314
# Epoch: 996, Custo: 3.930
# Epoch: 997, Custo: 3.859
# Epoch: 998, Custo: 4.140
# Epoch: 999, Custo: 3.847
# Epoch: 1000, Custo: 4.012

# %% [markdown]
# ## Fim
